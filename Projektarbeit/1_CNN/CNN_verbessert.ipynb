# %% [markdown]
# ## 2) Datenanalyse und Vorbereitung
# 2.1 Laden des CIFAR-10 Datensatzes

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
from sklearn.model_selection import train_test_split

def _unpickle(file_path: Path):
    with open(file_path, "rb") as f:
        return pickle.load(f, encoding="bytes")

def load_cifar10_local(datasets_dir: Path):
    datasets_dir = Path(datasets_dir)

    required = [datasets_dir / f"data_batch_{i}" for i in range(1, 6)] + [
        datasets_dir / "test_batch",
        datasets_dir / "batches.meta",
    ]
    missing = [p for p in required if not p.exists()]
    if missing:
        raise FileNotFoundError(
            "CIFAR-10 Dateien nicht gefunden. Fehlend:\n" + "\n".join(str(p) for p in missing)
            + "\n\nTipp: Öffne den Ordner `1_CNN` als Projekt/Workspace, damit `Path.cwd()` auf `1_CNN` zeigt."
        )

    meta = _unpickle(datasets_dir / "batches.meta")
    label_names = meta.get(b"label_names")
    class_names = [x.decode("utf-8") for x in label_names]

    xs, ys = [], []
    for i in range(1, 6):
        batch = _unpickle(datasets_dir / f"data_batch_{i}")
        xs.append(batch[b"data"])
        ys.extend(batch[b"labels"])

    x_train = np.vstack(xs).reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
    y_train = np.array(ys, dtype=np.int64)

    test = _unpickle(datasets_dir / "test_batch")
    x_test = test[b"data"].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)
    y_test = np.array(test[b"labels"], dtype=np.int64)

    return (x_train, y_train), (x_test, y_test), class_names

datasets_dir = Path.cwd() / "CNN_Datensätze"

(x_train_full, y_train_full), (x_test, y_test), class_names = load_cifar10_local(datasets_dir)

print("Lokal geladen!")
print("x_train_full:", x_train_full.shape, "y_train_full:", y_train_full.shape)
print("x_test:", x_test.shape, "y_test:", y_test.shape)
print("Klassen:", class_names)
# Out:
# C:\Users\cosen\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# C:\Users\cosen\AppData\Local\Temp\ipykernel_1668\402291609.py:12: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   return pickle.load(f, encoding="bytes")
# Lokal geladen!
# x_train_full: (50000, 32, 32, 3) y_train_full: (50000,)
# x_test: (10000, 32, 32, 3) y_test: (10000,)
# Klassen: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# 2.2 Durchführung einer ersten Exploration der Daten

# %%
counts_train = np.bincount(y_train_full, minlength=10)
plt.figure(figsize=(10,4))
plt.bar(class_names, counts_train)
plt.title("Klassenverteilung (Train gesamt)")
plt.ylabel("Anzahl")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

counts_test = np.bincount(y_test, minlength=10)
plt.figure(figsize=(10,4))
plt.bar(class_names, counts_test)
plt.title("Klassenverteilung (Test)")
plt.ylabel("Anzahl")
plt.xticks(rotation=30, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
shown = {i: False for i in range(10)}
idx = 0
pos = 1
while pos <= 10 and idx < len(x_train_full):
    label = int(y_train_full[idx])
    if not shown[label]:
        plt.subplot(2,5,pos)
        plt.imshow(x_train_full[idx])
        plt.title(class_names[label])
        plt.axis("off")
        shown[label] = True
        pos += 1
    idx += 1
plt.suptitle("Beispielbilder (je Klasse 1)")
plt.tight_layout()
plt.show()

# %% [markdown]
# 2.3 Daten aufbereiten und Normieren

# %%
x_train_full = x_train_full.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

print("Min/Max train:", x_train_full.min(), x_train_full.max())
print("Min/Max test:", x_test.min(), x_test.max())
# Out:
# Min/Max train: 0.0 1.0
# Min/Max test: 0.0 1.0

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomTranslation(0.1, 0.1),
])

# %% [markdown]
# 2.4 Datenaufteilung in Trainings-, Validierungs- und Testdatensatz

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=0.2,
    random_state=42,
    stratify=y_train_full
)

print("Train:", x_train.shape, y_train.shape)
print("Val:  ", x_val.shape, y_val.shape)
print("Test: ", x_test.shape, y_test.shape)

train_counts = np.bincount(y_train, minlength=10)
val_counts = np.bincount(y_val, minlength=10)

plt.figure(figsize=(10,4))
plt.plot(class_names, train_counts, marker="o", label="Train")
plt.plot(class_names, val_counts, marker="o", label="Val")
plt.title("Klassenverteilung: Train vs Val (stratifiziert)")
plt.ylabel("Anzahl")
plt.xticks(rotation=30, ha="right")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Train: (40000, 32, 32, 3) (40000,)
# Val:   (10000, 32, 32, 3) (10000,)
# Test:  (10000, 32, 32, 3) (10000,)

# %% [markdown]
# ---
# ## 3) Modellaufbau und Training
# 3.1 Erstellung und Training eines CNN

# %%
tf.random.set_seed(42)
np.random.seed(42)

model = keras.Sequential([
    layers.Input(shape=(32, 32, 3)),
    data_augmentation,

    layers.Conv2D(32, 3, padding="same", use_bias=False),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.Conv2D(32, 3, padding="same", use_bias=False),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),

    layers.Conv2D(64, 3, padding="same", use_bias=False),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.Conv2D(64, 3, padding="same", use_bias=False),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),

    layers.Conv2D(128, 3, padding="same", use_bias=False),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.Conv2D(128, 3, padding="same", use_bias=False),
    layers.BatchNormalization(),
    layers.Activation("relu"),
    layers.MaxPooling2D(),
    layers.Dropout(0.4),

    layers.GlobalAveragePooling2D(),
    layers.Dense(10, activation="softmax"),
])

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=3e-4),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(patience=3, factor=0.5),
    keras.callbacks.EarlyStopping(patience=6, restore_best_weights=True),
]

history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    batch_size=64,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 69s 106ms/step - accuracy: 0.3922 - loss: 1.6460 - val_accuracy: 0.4918 - val_loss: 1.3971 - learning_rate: 3.0000e-04
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.5065 - loss: 1.3573 - val_accuracy: 0.5361 - val_loss: 1.3705 - learning_rate: 3.0000e-04
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - accuracy: 0.5551 - loss: 1.2315 - val_accuracy: 0.5213 - val_loss: 1.4477 - learning_rate: 3.0000e-04
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - accuracy: 0.5892 - loss: 1.1424 - val_accuracy: 0.5700 - val_loss: 1.2421 - learning_rate: 3.0000e-04
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.6156 - loss: 1.0812 - val_accuracy: 0.5900 - val_loss: 1.1942 - learning_rate: 3.0000e-04
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.6371 - loss: 1.0275 - val_accuracy: 0.5221 - val_loss: 1.4156 - learning_rate: 3.0000e-04
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.6550 - loss: 0.9779 - val_accuracy: 0.6420 - val_loss: 1.0348 - learning_rate: 3.0000e-04
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - accuracy: 0.6689 - loss: 0.9378 - val_accuracy: 0.5752 - val_loss: 1.2625 - learning_rate: 3.0000e-04
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - accuracy: 0.6834 - loss: 0.9043 - val_accuracy: 0.6605 - val_loss: 1.0160 - learning_rate: 3.0000e-04
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.6949 - loss: 0.8769 - val_accuracy: 0.6858 - val_loss: 0.9204 - learning_rate: 3.0000e-04
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7029 - loss: 0.8477 - val_accuracy: 0.7065 - val_loss: 0.8796 - learning_rate: 3.0000e-04
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - accuracy: 0.7102 - loss: 0.8269 - val_accuracy: 0.7285 - val_loss: 0.7799 - learning_rate: 3.0000e-04
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.7192 - loss: 0.8077 - val_accuracy: 0.7247 - val_loss: 0.7933 - learning_rate: 3.0000e-04
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 106ms/step - accuracy: 0.7248 - loss: 0.7852 - val_accuracy: 0.7320 - val_loss: 0.7962 - learning_rate: 3.0000e-04
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.7329 - loss: 0.7692 - val_accuracy: 0.7409 - val_loss: 0.7585 - learning_rate: 3.0000e-04
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7368 - loss: 0.7548 - val_accuracy: 0.7415 - val_loss: 0.7481 - learning_rate: 3.0000e-04
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7432 - loss: 0.7374 - val_accuracy: 0.7499 - val_loss: 0.7351 - learning_rate: 3.0000e-04
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7463 - loss: 0.7295 - val_accuracy: 0.7751 - val_loss: 0.6501 - learning_rate: 3.0000e-04
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 108ms/step - accuracy: 0.7514 - loss: 0.7127 - val_accuracy: 0.7277 - val_loss: 0.8095 - learning_rate: 3.0000e-04
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7522 - loss: 0.7108 - val_accuracy: 0.7550 - val_loss: 0.7274 - learning_rate: 3.0000e-04
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7586 - loss: 0.6903 - val_accuracy: 0.7821 - val_loss: 0.6252 - learning_rate: 3.0000e-04
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 70s 112ms/step - accuracy: 0.7596 - loss: 0.6859 - val_accuracy: 0.7614 - val_loss: 0.6997 - learning_rate: 3.0000e-04
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7660 - loss: 0.6713 - val_accuracy: 0.7720 - val_loss: 0.6683 - learning_rate: 3.0000e-04
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.7710 - loss: 0.6633 - val_accuracy: 0.7560 - val_loss: 0.7241 - learning_rate: 3.0000e-04
# Epoch 25/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7846 - loss: 0.6252 - val_accuracy: 0.7806 - val_loss: 0.6470 - learning_rate: 1.5000e-04
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.7867 - loss: 0.6165 - val_accuracy: 0.7915 - val_loss: 0.6086 - learning_rate: 1.5000e-04
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 66s 106ms/step - accuracy: 0.7869 - loss: 0.6115 - val_accuracy: 0.7763 - val_loss: 0.6627 - learning_rate: 1.5000e-04
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.7877 - loss: 0.6100 - val_accuracy: 0.8022 - val_loss: 0.5771 - learning_rate: 1.5000e-04
# Epoch 29/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 68s 108ms/step - accuracy: 0.7915 - loss: 0.5987 - val_accuracy: 0.7865 - val_loss: 0.6235 - learning_rate: 1.5000e-04
# Epoch 30/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 65s 104ms/step - accuracy: 0.7921 - loss: 0.6008 - val_accuracy: 0.8027 - val_loss: 0.5844 - learning_rate: 1.5000e-04
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 120ms/step - accuracy: 0.7933 - loss: 0.5899 - val_accuracy: 0.8075 - val_loss: 0.5667 - learning_rate: 1.5000e-04
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 136ms/step - accuracy: 0.7911 - loss: 0.5959 - val_accuracy: 0.7933 - val_loss: 0.6151 - learning_rate: 1.5000e-04
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 121ms/step - accuracy: 0.7947 - loss: 0.5849 - val_accuracy: 0.8098 - val_loss: 0.5542 - learning_rate: 1.5000e-04
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 130ms/step - accuracy: 0.7972 - loss: 0.5817 - val_accuracy: 0.7998 - val_loss: 0.5855 - learning_rate: 1.5000e-04
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 137ms/step - accuracy: 0.7999 - loss: 0.5730 - val_accuracy: 0.7995 - val_loss: 0.6049 - learning_rate: 1.5000e-04
# Epoch 36/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 90s 144ms/step - accuracy: 0.8023 - loss: 0.5702 - val_accuracy: 0.8176 - val_loss: 0.5408 - learning_rate: 1.5000e-04
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 90s 143ms/step - accuracy: 0.8023 - loss: 0.5686 - val_accuracy: 0.8107 - val_loss: 0.5512 - learning_rate: 1.5000e-04
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 88s 140ms/step - accuracy: 0.8020 - loss: 0.5682 - val_accuracy: 0.8039 - val_loss: 0.5674 - learning_rate: 1.5000e-04
# Epoch 39/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 89s 142ms/step - accuracy: 0.8022 - loss: 0.5672 - val_accuracy: 0.8141 - val_loss: 0.5462 - learning_rate: 1.5000e-04
# Epoch 40/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 89s 142ms/step - accuracy: 0.8127 - loss: 0.5427 - val_accuracy: 0.8105 - val_loss: 0.5646 - learning_rate: 7.5000e-05
# Epoch 41/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 87s 139ms/step - accuracy: 0.8124 - loss: 0.5396 - val_accuracy: 0.8111 - val_loss: 0.5493 - learning_rate: 7.5000e-05
# Epoch 42/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 87s 140ms/step - accuracy: 0.8126 - loss: 0.5379 - val_accuracy: 0.8200 - val_loss: 0.5315 - learning_rate: 7.5000e-05
# Epoch 43/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 138ms/step - accuracy: 0.8135 - loss: 0.5355 - val_accuracy: 0.8152 - val_loss: 0.5419 - learning_rate: 7.5000e-05
# Epoch 44/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 138ms/step - accuracy: 0.8154 - loss: 0.5327 - val_accuracy: 0.8181 - val_loss: 0.5405 - learning_rate: 7.5000e-05
# Epoch 45/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 86s 137ms/step - accuracy: 0.8149 - loss: 0.5315 - val_accuracy: 0.8226 - val_loss: 0.5208 - learning_rate: 7.5000e-05
# Epoch 46/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 92s 147ms/step - accuracy: 0.8140 - loss: 0.5332 - val_accuracy: 0.8139 - val_loss: 0.5668 - learning_rate: 7.5000e-05
# Epoch 47/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 91s 145ms/step - accuracy: 0.8160 - loss: 0.5296 - val_accuracy: 0.8179 - val_loss: 0.5421 - learning_rate: 7.5000e-05
# Epoch 48/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 92s 148ms/step - accuracy: 0.8153 - loss: 0.5268 - val_accuracy: 0.8228 - val_loss: 0.5300 - learning_rate: 7.5000e-05
# Epoch 49/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 87s 140ms/step - accuracy: 0.8185 - loss: 0.5236 - val_accuracy: 0.8189 - val_loss: 0.5342 - learning_rate: 3.7500e-05
# Epoch 50/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 87s 139ms/step - accuracy: 0.8236 - loss: 0.5114 - val_accuracy: 0.8178 - val_loss: 0.5387 - learning_rate: 3.7500e-05

# %%
hist = history.history

plt.figure(figsize=(8,5))
plt.plot(hist["loss"], marker="o", label="Train Loss")
plt.plot(hist["val_loss"], marker="o", label="Val Loss")
plt.title("Loss über Epochen")
plt.xlabel("Epoche")
plt.ylabel("Loss")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(8,5))
plt.plot(hist["accuracy"], marker="o", label="Train Accuracy")
plt.plot(hist["val_accuracy"], marker="o", label="Val Accuracy")
plt.title("Accuracy über Epochen")
plt.xlabel("Epoche")
plt.ylabel("Accuracy")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluation auf dem Testdatensatz

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Test Loss: 0.5487
# Test Accuracy: 0.8188

# %% [markdown]
# ## Optional: Beispielvorhersagen

# %%
num_show =25

idxs = np.random.choice(len(x_test), size=num_show, replace=False)

pred = model.predict(x_test[idxs], verbose=0)
pred_labels = np.argmax(pred, axis=1)

plt.figure(figsize=(20,10))
for i, idx in enumerate(idxs, start=1):
    plt.subplot(5,5,i)
    plt.imshow(x_test[idx])
    true_label = class_names[int(y_test[idx])]
    pred_label = class_names[int(pred_labels[i-1])]
    plt.title(f"T: {true_label}\nP: {pred_label}")
    plt.axis("off")

plt.suptitle("Beispielvorhersagen (Test)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 num_show =25
# ----> 3 idxs = np.random.choice(len(x_test), size=num_show, replace=False)
#       5 pred = model.predict(x_test[idxs], verbose=0)
#       6 pred_labels = np.argmax(pred, axis=1)
#
# NameError: name 'np' is not defined
